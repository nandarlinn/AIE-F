# %% [markdown]
# # WER Calculation
# ## for AI Fundamental Class Students
# by Ye Kyaw Thu, Language Understanding Lab., Myanmar
# Date: 9 May 2026
#
# Machine translation, ASR သုတေသန လုပ်ကြမယ်ဆိုရင် WER ကို အသေးစိတ် တွက်တတ်ဖို့ လိုအပ်ပါတယ်။ တကယ်တမ်းကတော့ တခြား NLP task တွေအတွက်လည်း အသုံးဝင်ပါတယ်။ SCTK toolkit ထဲက ပါလာတဲ့ sclite ပရိုဂရမ်ကို သုံးပြီး ရှေ့ကလုပ်ခဲ့ကြတဲ့ ထိုင်း-မြန်မာ machine translation ရလဒ် စာကြောင်း ၁၀ကြောင်းကို ဥပမာအနေနဲ့ သုံးပြီးတွက်ပြပါမယ်။
#
# SCTK Toolkit: [https://github.com/usnistgov/SCTK](https://github.com/usnistgov/SCTK)
# For your reference: [https://github.com/ye-kyaw-thu/NLP-Class/tree/master/exercise/exe-6](https://github.com/ye-kyaw-thu/NLP-Class/tree/master/exercise/exe-6)

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial'

# %%
# %mkdir wer

# %%
# %cd wer
# Out:
# /home/ye/exp/SMT-NMT_tutorial/wer

# %% [markdown]
# ## Help (--help of sclite)

# %%
# !/home/ye/tool/SCTK/bin/sclite
# Out:
# sclite: <OPTIONS>
# sclite Version: 2.10, SCTK Version: 1.3
# Input Options:
#     -r reffile [ <rfmt> ]
#                 Define the reference file, and it's format
#     -h hypfile [ <hfmt> <title> ]
#                 Define the hypothesis file, it's format, and a 'title' used
#                 for reports.  The default title is 'hypfile'.  This option
#                 may be used more than once.
#     -i <ids>    Set the utterance id type.   (for transcript mode only)
#     -P          Accept the piped input from another utility.
#     -e gb|euc|utf-8 [ case-conversion-localization ]
#                 Interpret characters as GB, EUC, utf-8, or the default, 8-bit ASCII.
#                 Optionally, case conversion localization can be set to either 'generic',
#                 'babel_turkish', or 'babel_vietnamese', 'ukranian'
# Alignment Options:
#     -s          Do Case-sensitive alignments.
#     -d          Use GNU diff for alignments.
#     -c [ NOASCII DH ]
# ...

# %% [markdown]
# ## Prepare Reference and Hypothesis Files
#
# 1st Example အနေနဲ့ ထိုင်း-မြန်မာ MT က ထွက်လာတဲ့ hyp ဖိုင်နဲ့ test data reference ဖိုင်ကိုပဲ နှိုင်းယှဉ်ပြီး WER တွက်တာကို လက်တွေ့ လုပ်ပြပါမယ်။ အဲဒီအတွက် ဖိုင်တွေကို ပြင်မယ်။

# %%
# %mkdir mt

# %%
# %cd mt
# Out:
# /home/ye/exp/SMT-NMT_tutorial/wer/mt

# %%
# !cp /home/ye/exp/SMT-NMT_tutorial/pbsmt-big-normalize/baseline/th-my/evaluation/*.raw .

# %%
# !cat ./th-my.ref.raw
# Out:
# ခွဲ မှ ရ မှာ လား
# မျက် ခံ လှုပ် တဲ့ လက္ခ ဏာ ရှိ မယ်
# အ ရက် ကို စွန့် လွှတ် ရ မည် ဖြစ် ပြီး ပ ရို တင်း နှင့် ဗီ တာ မင် ဓာတ် ကြွယ် ဝ သော အာ ဟာ ရ ရှိ သော အ စား အ စာ များ ကို စား သင့် သည်
# ဟုတ် ကဲ့ သူ ဖျား ပါ တယ် သူ သီး သန့် တော့ မ နေ ခဲ့ ဘူး
# မောင် လေး နောက် ဆုံး အ ကြိမ် ဆေး သောက် ခဲ့ တာ ဘယ် ချိန် လဲ
# ကိုယ် မှာ ကူး စက် တာ က နေ ဦး နှောက် ထိ ပါ ကူး စက် လာ တယ်
# မစ် စ တာ ပ ရာ မို့ ရဲ့ ဆွေ မျိုး ဝင် လာ ဖို့ တစ် ချက် ခေါ် ပေး ပါ ရှင်
# အ ချို ကို လျော့ ချ ကြည့် လိုက် ပါ
# သူ တို့ နဲ့ အ တူ တူ ရှိ နေ တယ် လို့ ပဲ တွေး မိ နေ တယ် ဗျာ
# ဆေး ယူ ပြီး ပြီ ဆို ရင် တော့ အိမ် ပြန် လို့ ရ ပြီ နော်

# %%
# !cat ./th-my.hyp.raw
# Out:
# ခွဲ ဖို့ လို သေး လား
# မျက် ခွံ တွေ လှုပ် မယ်
# ခင် ဗျား အ ရက် သောက် ခြင်း ကို ရှောင် ရ မယ် အ ကျိုး ရှိ သည့် အ စား အ စာ နဲ့ ဓာတ် ကြွယ် ဝ ပ ရို တင်း နဲ့ ဗီ တာ မင် တွေ
# သူ မ ဖျား ပါ တယ် ပြီး တော့ သူ မ တွင် သီး သန့် နေ ထိုင် လို့ မ ရ ပါ ဘူး
# နောက် ဆုံး အ ကြိမ် သောက် တဲ့ ချိန် က ဘယ် ချိန် လဲ
# ခန္ဓာ ကိုယ် က နေ ဦး နှောက် ကို ပါ ပိုး ကူး စက် ခြင်း
# မစ် တာ ပ ရာ မို့ လူ နာ စောင့် ဝင် လာ ဖို့ တစ် ချက် ခေါ် ပေး ပါ ရှင်
# ချို တာ တွေ ကို လျော့ ကြည့် ပါ
# သူ တို့ တယ် လို့ ပဲ ထင် နေ တာ နဲ့ ပတ် သက် ပြီး ကျွန် တော် အ တူ တူ ပဲ ရှိ ပါ သေး တယ်
# ဆေး ယူ ပြီး ရင် တော့ အိမ် ပြန် လို့ ရ ပါ ပြီ ခင် ဗျာ

# %% [markdown]
# ## Adding Speaker ID
#
# SCTK toolkit ရဲ့ format က speaker ID တပ်ဖို့ လိုတာမို့ dummy speaker-id တပ်ရအောင်။

# %%
# !cat ./tag-id.pl
# Out:
# #!/usr/bin/perl
#
# use strict;
# use warnings;
# use utf8;
#
# binmode(STDIN, ":utf8");
# binmode(STDOUT, ":utf8");
# binmode(STDERR, ":utf8");
#
# my $lineNum=0;
#
# open (my $inputFILE,"<:encoding(utf8)", $ARGV[0]) or die "Couldn't open input file $ARGV[0]!, $!\n";
#
# while (!eof($inputFILE)) {
#
#     my $line = <$inputFILE>;
#     if (($line ne '') & ($line !~ /^ *$/)) {
#         chomp($line);
#         $line =~ s/^\s+|\s+$//g; #remove spaces at the start and end of sentences
#         $line =~ s/ +/ /g;  #remove multiple spaces between words
#         $lineNum=$lineNum+1;
#         print "$line (ye_$lineNum)\n";
#   }
# }
# close ($inputFILE);

# %% [markdown]
# ### Speaker ID Tagging for Reference File

# %%
# !perl ./tag-id.pl ./th-my.ref.raw > th-my.ref

# %%
# !cat ./th-my.ref
# Out:
# ခွဲ မှ ရ မှာ လား (ye_1)
# မျက် ခံ လှုပ် တဲ့ လက္ခ ဏာ ရှိ မယ် (ye_2)
# အ ရက် ကို စွန့် လွှတ် ရ မည် ဖြစ် ပြီး ပ ရို တင်း နှင့် ဗီ တာ မင် ဓာတ် ကြွယ် ဝ သော အာ ဟာ ရ ရှိ သော အ စား အ စာ များ ကို စား သင့် သည် (ye_3)
# ဟုတ် ကဲ့ သူ ဖျား ပါ တယ် သူ သီး သန့် တော့ မ နေ ခဲ့ ဘူး (ye_4)
# မောင် လေး နောက် ဆုံး အ ကြိမ် ဆေး သောက် ခဲ့ တာ ဘယ် ချိန် လဲ (ye_5)
# ကိုယ် မှာ ကူး စက် တာ က နေ ဦး နှောက် ထိ ပါ ကူး စက် လာ တယ် (ye_6)
# မစ် စ တာ ပ ရာ မို့ ရဲ့ ဆွေ မျိုး ဝင် လာ ဖို့ တစ် ချက် ခေါ် ပေး ပါ ရှင် (ye_7)
# အ ချို ကို လျော့ ချ ကြည့် လိုက် ပါ (ye_8)
# သူ တို့ နဲ့ အ တူ တူ ရှိ နေ တယ် လို့ ပဲ တွေး မိ နေ တယ် ဗျာ (ye_9)
# ဆေး ယူ ပြီး ပြီ ဆို ရင် တော့ အိမ် ပြန် လို့ ရ ပြီ နော် (ye_10)

# %% [markdown]
# ### Speaker ID Tagging for Hypothesis File

# %%
# !perl ./tag-id.pl ./th-my.hyp.raw > th-my.hyp

# %%
# !cat ./th-my.hyp
# Out:
# ခွဲ ဖို့ လို သေး လား (ye_1)
# မျက် ခွံ တွေ လှုပ် မယ် (ye_2)
# ခင် ဗျား အ ရက် သောက် ခြင်း ကို ရှောင် ရ မယ် အ ကျိုး ရှိ သည့် အ စား အ စာ နဲ့ ဓာတ် ကြွယ် ဝ ပ ရို တင်း နဲ့ ဗီ တာ မင် တွေ (ye_3)
# သူ မ ဖျား ပါ တယ် ပြီး တော့ သူ မ တွင် သီး သန့် နေ ထိုင် လို့ မ ရ ပါ ဘူး (ye_4)
# နောက် ဆုံး အ ကြိမ် သောက် တဲ့ ချိန် က ဘယ် ချိန် လဲ (ye_5)
# ခန္ဓာ ကိုယ် က နေ ဦး နှောက် ကို ပါ ပိုး ကူး စက် ခြင်း (ye_6)
# မစ် တာ ပ ရာ မို့ လူ နာ စောင့် ဝင် လာ ဖို့ တစ် ချက် ခေါ် ပေး ပါ ရှင် (ye_7)
# ချို တာ တွေ ကို လျော့ ကြည့် ပါ (ye_8)
# သူ တို့ တယ် လို့ ပဲ ထင် နေ တာ နဲ့ ပတ် သက် ပြီး ကျွန် တော် အ တူ တူ ပဲ ရှိ ပါ သေး တယ် (ye_9)
# ဆေး ယူ ပြီး ရင် တော့ အိမ် ပြန် လို့ ရ ပါ ပြီ ခင် ဗျာ (ye_10)

# %% [markdown]
# ## WER Calculation (Summary)
#
# Reference link: [https://en.wikipedia.org/wiki/Word_error_rate](https://en.wikipedia.org/wiki/Word_error_rate)
# Levenshtein Distance Reference: [https://en.wikipedia.org/wiki/Levenshtein_distance](https://en.wikipedia.org/wiki/Levenshtein_distance)
#
# ပထမဆုံး Summary အနေနဲ့ပဲ တွက်ခိုင်းမယ်။

# %%
 # !/home/ye/tool/SCTK/bin/sclite -r ./th-my.ref -h ./th-my.hyp -i spu_id
# Out:
# sclite: 2.10 TK Version 1.3
# Begin alignment of Ref File: './th-my.ref' and Hyp File: './th-my.hyp'
#     Alignment# 10 for speaker ye
#
#
#
#
#                      SYSTEM SUMMARY PERCENTAGES by SPEAKER
#
#        ,----------------------------------------------------------------.
#        |                          ./th-my.hyp                           |
#        |----------------------------------------------------------------|
#        | SPKR   | # Snt # Wrd | Corr    Sub    Del    Ins    Err  S.Err |
#        |--------+-------------+-----------------------------------------|
#        | ye     |   10    144 | 51.4   25.7   22.9   20.8   69.4  100.0 |
#        |================================================================|
#        | Sum/Avg|   10    144 | 51.4   25.7   22.9   20.8   69.4  100.0 |
#        |================================================================|
#        |  Mean  | 10.0  144.0 | 51.4   25.7   22.9   20.8   69.4  100.0 |
# ...

# %% [markdown]
# ## with Per-Utterance Alignment (-o pra) Option
#
# With -pra option နဲ့ ဆိုရင် စာကြောင်း တစ်ကြောင်းချင်းစီအတွက် Reference နဲ့ Hypothesis အကြား ဘယ်လိုပုံစံမျိုးနဲ့ alignment လုပ်သွားတယ် ဆိုတာကို အသေးစိတ်ထုတ်ပေးပါလိမ့်မယ်။

# %%
# !/home/ye/tool/SCTK/bin/sclite -r ./th-my.ref -h ./th-my.hyp -i spu_id -o pra
# Out:
# sclite: 2.10 TK Version 1.3
# Begin alignment of Ref File: './th-my.ref' and Hyp File: './th-my.hyp'
#     Alignment# 10 for speaker ye
#
#     Writing string alignments to 'th-my.hyp.pra'
#
# Successful Completion

# %%
# !ls *
# Out:
# tag-id.pl  th-my.hyp  th-my.hyp.pra  th-my.hyp.raw  th-my.ref  th-my.ref.raw

# %%
# !cat th-my.hyp.pra
# Out:
# 		DUMP OF SYSTEM ALIGNMENT STRUCTURE
#
# System name:   ./th-my.hyp
#
# Speakers:
#     0:  ye
#
# Speaker sentences   0:  ye   #utts: 10
# id: (ye_1)
# Scores: (#C #S #D #I) 2 3 0 0
# REF:  ခွဲ မှ       ရ       မှာ လား
# HYP:  ခွဲ ဖို့ လို သေး လား
# Eval:           S            S         S
#
# id: (ye_2)
# Scores: (#C #S #D #I) 3 1 4 1
# REF:  မျက် ********* ခံ    လှုပ် တဲ့ လက္ခ ဏာ ရှိ မယ်
# HYP:  မျက် ခွံ တွေ လှုပ် ********* ************ ****** ********* မယ်
# Eval:              I         S                         D         D            D      D
#
# id: (ye_3)
# Scores: (#C #S #D #I) 7 19 8 4
# REF:  ********* ************ အ ရက် *************** *************** ကို စွန့် လွှတ်    ရ မည် ဖြစ် ပြီး    ပ       ရို    တင်း နှင့် ဗီ တာ မင် ဓာတ် ကြွယ် ဝ သော အာ ဟာ ရ ရှိ သော အ စား အ       စာ       များ ကို စား သင့် သည်
# ...

# %% [markdown]
# ## with Detailed Summary Statistics (-o dtl) Option
# Detail Calculation နဲ့ ဆိုရင်တော့ top confusion pair တွေကို လေ့လာလို့ ရလိမ့်မယ်။

# %%
# !/home/ye/tool/SCTK/bin/sclite -r ./th-my.ref -h ./th-my.hyp -i spu_id -o dtl
# Out:
# sclite: 2.10 TK Version 1.3
# Begin alignment of Ref File: './th-my.ref' and Hyp File: './th-my.hyp'
#     Alignment# 10 for speaker ye
#
#     Writing overall detailed scoring report 'th-my.hyp.dtl'
#
# Successful Completion

# %%
# !ls *
# Out:
# tag-id.pl  th-my.hyp.dtl  th-my.hyp.raw  th-my.ref.raw
# th-my.hyp  th-my.hyp.pra  th-my.ref

# %%
# !cat th-my.hyp.dtl
# Out:
# DETAILED OVERALL REPORT FOR THE SYSTEM: ./th-my.hyp
#
# SENTENCE RECOGNITION PERFORMANCE
#
#  sentences                                          10
#  with errors                            100.0%   (  10)
#
#    with substitutions                    90.0%   (   9)
#    with deletions                        90.0%   (   9)
#    with insertions                       80.0%   (   8)
#
#
# WORD RECOGNITION PERFORMANCE
#
# Percent Total Error       =   69.4%   ( 100)
#
# Percent Correct           =   51.4%   (  74)
#
# Percent Substitution      =   25.7%   (  37)
# Percent Deletions         =   22.9%   (  33)
# Percent Insertions        =   20.8%   (  30)
# Percent Word Accuracy     =   30.6%
#
#
# Ref. words                =           ( 144)
# Hyp. words                =           ( 141)
# Aligned words             =           ( 174)
#
# CONFUSION PAIRS                  Total                 (37)
#                                  With >=  1 occurrences (37)
#
# ...
